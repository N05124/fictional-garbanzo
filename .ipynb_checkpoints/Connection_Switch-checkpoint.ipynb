# %%
def status_response():
    match point:
        point == 'origin':
            match status:
                status == 'step x': # suitable nomenclature?
                    return None     # do something.
                status == 'step y':
                    return None
                status == 'step z':
                    return None
        point == 'pivot':
            match status:
                status == 'step x': # suitable nomenclature?
                    return None
                status == 'step y':
                    return None
                status == 'step z':
                    return None
        point == 'storage':
            match status:
                status == 'step x': # suitable nomenclature?
                    return None
                status == 'step y':
                    return None
                status == 'step z':
                    return None
