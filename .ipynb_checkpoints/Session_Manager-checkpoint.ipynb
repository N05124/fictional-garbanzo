# %%
# server usage - [cmd: server] <ip>
# handles LAN / WAN access
def remote_browser(IP):
    if input(f'{IP} is correct: [y/n]') == 'y':
        subprocess.run(f'server {$IP}') # server script /usr/local/bin/server.sh?
        # local broadcast
        # WAN broadcast
    else:
        exit() # exit condition - do something

# %%
def ssh(username, ip):
    subprocess.run(f'ssh {username}@{ip}')
    capture_output(True, input('enter password'))
    # secure capture of password ???
