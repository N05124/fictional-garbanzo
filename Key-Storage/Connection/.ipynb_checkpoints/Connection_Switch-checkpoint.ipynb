# %% [markdown]
# # Status will relay credentials whereabouts

# %% [markdown]
# ## Origin point cases: prototype
# - credential is at origin point && does not have storage location
# - credential is at origin point && is not verified
# - credential is at origin point && is verified
# - credential is at origin point && has transmitted
# - credential is at origin point && has storage location
# - credential is at origin point && storage location has been validated
# - credential is at origin point && credential has been validated on return

# %% [markdown]
# ## Pivot point cases: prototype
# - session has been initiated
# - session has dedicated location
# - location determines:
#     - location is on current device
#     - location is on external device

# %% [markdown]
# ### Location Cases on current device
# - current device passes credentialed storage (rating)
# - current device allocated storage
# - current device validates alias
# - current device selects blockchain
#     - Blockchain API's suitable for local storage?

# %% [markdown]
# ### Location Cases on external device

# %% [markdown]
# ## Storage Location cases: prototype
# ### Storage cases will elaborate on session validation
# ### and origin point credential testing phase pre-storage
# ### finalize and send to *blockchain (local)

# %%
def status_response():
    match point:
        point == 'origin':
            match status:
                status == 'step x': # suitable nomenclature?
                    return None     # do something.
                status == 'step y':
                    return None
                status == 'step z':
                    return None
        point == 'pivot':
            match status:
                status == 'step x': # suitable nomenclature?
                    return None
                status == 'step y':
                    return None
                status == 'step z':
                    return None
        point == 'storage':
            match status:
                status == 'step x': # suitable nomenclature?
                    return None
                status == 'step y':
                    return None
                status == 'step z':
                    return None
