# %%
"""
ssh_daemon.py
-------------
Persistent background process that:
  - Listens for incoming encrypted credentials over LAN or WAN
  - Validates and stores credentials in a local hash-chained ledger (mini blockchain)
  - Reconnects automatically on network loss
  - Communicates with remote_desktop.py Flask server via shared protocol

Designed to run as a systemd service.

Usage (direct):
    python3 ssh_daemon.py

Usage (systemd):
    See credential-daemon.service
"""

import os
import json
import time
import socket
import signal
import hashlib
import logging
import threading
from datetime import datetime, timezone
from pathlib import Path
from cryptography.fernet import Fernet, InvalidToken

# ── Config ────────────────────────────────────────────────────────────────

LISTEN_HOST    = "0.0.0.0"       # bind all interfaces (LAN + WAN)
LISTEN_PORT    = int(os.environ.get("DAEMON_PORT", 9922))
# KEY_PATH       = Path(os.environ.get("FERNET_KEY_PATH",  "/etc/credential-daemon/fernet.key"))
# LEDGER_PATH    = Path(os.environ.get("LEDGER_PATH",      "/var/lib/credential-daemon/ledger.json"))
# LOG_PATH       = Path(os.environ.get("LOG_PATH",         "/var/log/credential-daemon/daemon.log"))
KEY_PATH       = Path(os.environ.get("FERNET_KEY_PATH",  ".//fernet.key"))
LEDGER_PATH    = Path(os.environ.get("LEDGER_PATH",      "./ledger.json"))
LOG_PATH       = Path(os.environ.get("LOG_PATH",         "./daemon.log"))

RECONNECT_WAIT = int(os.environ.get("RECONNECT_WAIT",    5))    # seconds between retries
MAX_CONN_QUEUE = int(os.environ.get("MAX_CONN_QUEUE",    5))    # socket backlog
RECV_TIMEOUT   = int(os.environ.get("RECV_TIMEOUT",      30))   # per-connection timeout (s)
MAX_MSG_BYTES  = int(os.environ.get("MAX_MSG_BYTES",     4096))  # max incoming message size

# ── Logging ───────────────────────────────────────────────────────────────

LOG_PATH.parent.mkdir(parents=True, exist_ok=True)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler(LOG_PATH),
        logging.StreamHandler(),          # also print to stdout → journald
    ]
)
log = logging.getLogger("credential-daemon")

# %%
# ── Fernet key ────────────────────────────────────────────────────────────

def load_or_create_key() -> Fernet:
    KEY_PATH.parent.mkdir(parents=True, exist_ok=True)
    if KEY_PATH.exists():
        key = KEY_PATH.read_bytes()
        log.info(f"Loaded Fernet key from {KEY_PATH}")
    else:
        key = Fernet.generate_key()
        KEY_PATH.write_bytes(key)
        KEY_PATH.chmod(0o600)
        log.info(f"Generated new Fernet key at {KEY_PATH}")
    return Fernet(key)

# %%
print(load_or_create_key())
# Out:
# 2026-05-05 12:06:26,504 [INFO] Loaded Fernet key from fernet.key
# ...

# %%
# ── Message protocol ──────────────────────────────────────────────────────
#
#  Every message is a newline-terminated JSON object:
#  { "type": "credential", "key_hash": "<hex>", "encrypted": "<hex>" }
#  { "type": "ping" }
#  { "type": "verify" }   → daemon responds with chain validity

def handle_message(raw: bytes, ledger: Ledger, fernet: Fernet) -> dict:
    try:
        msg = json.loads(raw.decode().strip())
    except (json.JSONDecodeError, UnicodeDecodeError):
        return {"status": "error", "reason": "invalid JSON"}

    msg_type = msg.get("type")

    if msg_type == "ping":
        return {"status": "ok", "type": "pong"}

    if msg_type == "verify":
        valid = ledger.is_valid()
        return {"status": "ok", "chain_valid": valid, "length": len(ledger.chain)}

    if msg_type == "credential":
        key_hash  = msg.get("key_hash", "")
        encrypted = msg.get("encrypted", "")

        if not key_hash or not encrypted:
            return {"status": "error", "reason": "missing key_hash or encrypted"}

        # Verify we can decrypt it (proves we share the Fernet key)
        try:
            enc_bytes = bytes.fromhex(encrypted)
            fernet.decrypt(enc_bytes)
        except (InvalidToken, ValueError):
            return {"status": "error", "reason": "decryption failed — key mismatch or tampered payload"}

        block = ledger.append(key_hash, enc_bytes)
        return {"status": "ok", "block_index": block["index"], "block_hash": block["block_hash"]}

    return {"status": "error", "reason": f"unknown message type: {msg_type}"}

# %%
#test stub for handle message() 
import json
from cryptography.fernet import Fernet
import hashlib

# --- dummy ledger ---
class Ledger:
    def __init__(self):
        self.chain = []

    def append(self, key_hash, enc_bytes):
        block = {
            "index": len(self.chain),
            "block_hash": hashlib.sha256(enc_bytes).hexdigest()
        }
        self.chain.append(block)
        return block

    def is_valid(self):
        return True

# --- setup ---
key = Fernet.generate_key()
fernet = Fernet(key)
ledger = Ledger()

# --- create valid encrypted payload ---
plaintext = b"secret credential"
encrypted_bytes = fernet.encrypt(plaintext)

message = {
    "type": "credential",
    "key_hash": hashlib.sha256(b"mykey").hexdigest(),
    "encrypted": encrypted_bytes.hex()
}

raw = (json.dumps(message) + "\n").encode()

# --- call ---
response = handle_message(raw, ledger, fernet)
print(response)
# Out:
# {'status': 'ok', 'block_index': 0, 'block_hash': '157df33745234c62a1356c4bbdfc710d9f6485dfac19281906e183e8d921cf5c'}

# %%
# ── Connection handler ────────────────────────────────────────────────────

def handle_connection(conn: socket.socket, addr: tuple, ledger: Ledger, fernet: Fernet):
    ip, port = addr
    log.info(f"Connection from {ip}:{port}")
    conn.settimeout(RECV_TIMEOUT)
    try:
        data = conn.recv(MAX_MSG_BYTES)
        if not data:
            return
        response = handle_message(data, ledger, fernet)
        conn.sendall((json.dumps(response) + "\n").encode())
    except socket.timeout:
        log.warning(f"Connection from {ip} timed out.")
    except Exception as e:
        log.error(f"Error handling {ip}: {e}")
    finally:
        conn.close()

# %%
#handle connection test stub
import socket
import threading
import json
import hashlib
from cryptography.fernet import Fernet

# --- dummy ledger ---
class Ledger:
    def __init__(self):
        self.chain = []

    def append(self, key_hash, enc_bytes):
        block = {
            "index": len(self.chain),
            "block_hash": hashlib.sha256(enc_bytes).hexdigest()
        }
        self.chain.append(block)
        return block

    def is_valid(self):
        return True

# --- test server ---
def start_test_server(host, port, ledger, fernet):
    server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    server.bind((host, port))
    server.listen(1)

    conn, addr = server.accept()
    handle_connection(conn, addr, ledger, fernet)

    server.close()

# --- setup ---
host = "127.0.0.1"
port = 9000

ledger = Ledger()
key = Fernet.generate_key()
fernet = Fernet(key)

# start server in background
thread = threading.Thread(
    target=start_test_server,
    args=(host, port, ledger, fernet),
    daemon=True
)
thread.start()

# --- create valid message ---
plaintext = b"secret credential"
encrypted = fernet.encrypt(plaintext)

message = {
    "type": "credential",
    "key_hash": hashlib.sha256(b"mykey").hexdigest(),
    "encrypted": encrypted.hex()
}

# --- client ---
with socket.create_connection((host, port)) as sock:
    sock.sendall((json.dumps(message) + "\n").encode())
    response = sock.recv(4096)

print("Server response:", response.decode())
# Out:
# 2026-05-05 12:18:07,327 [INFO] Connection from 127.0.0.1:60427
# Server response: {"status": "ok", "block_index": 0, "block_hash": "289c1410e0c352d424b9ba2bbf02156de2f4fd558a84550a494456926086b5f7"}

# %%
# ── Daemon main loop ──────────────────────────────────────────────────────

class CredentialDaemon:
    def __init__(self):
        self.fernet  = load_or_create_key()
        self.ledger  = Ledger(LEDGER_PATH)
        self._stop   = threading.Event()

        signal.signal(signal.SIGTERM, self._handle_signal)
        signal.signal(signal.SIGINT,  self._handle_signal)

    def _handle_signal(self, signum, frame):
        log.info(f"Signal {signum} received — shutting down.")
        self._stop.set()

    def run(self):
        log.info(f"Credential daemon starting on {LISTEN_HOST}:{LISTEN_PORT}")
        while not self._stop.is_set():
            try:
                self._listen()
            except OSError as e:
                log.error(f"Socket error: {e} — retrying in {RECONNECT_WAIT}s")
                time.sleep(RECONNECT_WAIT)
        log.info("Daemon stopped.")

    def _listen(self):
        with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as srv:
            srv.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
            srv.bind((LISTEN_HOST, LISTEN_PORT))
            srv.listen(MAX_CONN_QUEUE)
            srv.settimeout(2.0)   # allows stop event to be checked
            log.info(f"Listening on port {LISTEN_PORT} (LAN + WAN)")

            while not self._stop.is_set():
                try:
                    conn, addr = srv.accept()
                    t = threading.Thread(
                        target=handle_connection,
                        args=(conn, addr, self.ledger, self.fernet),
                        daemon=True,
                    )
                    t.start()
                except socket.timeout:
                    continue  # just re-check stop event

# %%
import threading
import socket
import json
import time
import hashlib
from cryptography.fernet import Fernet

# --- test config ---
LISTEN_HOST = "127.0.0.1"
LISTEN_PORT = 9101
LEDGER_PATH = "test_ledger.json"

# --- compatible Ledger ---
class Ledger:
    def __init__(self, path):
        self.path = path
        self.chain = []

    def append(self, key_hash, enc_bytes):
        block = {
            "index": len(self.chain),
            "block_hash": hashlib.sha256(enc_bytes).hexdigest()
        }
        self.chain.append(block)
        return block

    def is_valid(self):
        return True

# --- stub key loader ---
def load_or_create_key():
    return Fernet(Fernet.generate_key())

# --- start daemon ---
daemon = CredentialDaemon()

thread = threading.Thread(target=daemon.run, daemon=True)
thread.start()

time.sleep(1)  # allow server to start

# --- client helper ---
def send_message(msg):
    with socket.create_connection((LISTEN_HOST, LISTEN_PORT)) as sock:
        sock.sendall((json.dumps(msg) + "\n").encode())
        return sock.recv(4096).decode()

# --- tests ---
print("PING:", send_message({"type": "ping"}))
print("VERIFY:", send_message({"type": "verify"}))

fernet = daemon.fernet
encrypted = fernet.encrypt(b"test-secret")

msg = {
    "type": "credential",
    "key_hash": hashlib.sha256(b"mykey").hexdigest(),
    "encrypted": encrypted.hex()
}

print("CREDENTIAL:", send_message(msg))

# --- shutdown ---
daemon._stop.set()
thread.join(timeout=2)

print("Done.")
# Out:
# 2026-05-05 12:20:57,459 [INFO] Credential daemon starting on 127.0.0.1:9101
# 2026-05-05 12:20:57,460 [INFO] Listening on port 9101 (LAN + WAN)
# 2026-05-05 12:20:58,464 [INFO] Connection from 127.0.0.1:60595
# 2026-05-05 12:20:58,472 [INFO] Connection from 127.0.0.1:60596
# 2026-05-05 12:20:58,477 [INFO] Connection from 127.0.0.1:60597
# PING: {"status": "ok", "type": "pong"}
#
# VERIFY: {"status": "ok", "chain_valid": true, "length": 0}
#
# CREDENTIAL: {"status": "ok", "block_index": 0, "block_hash": "c4737592f3ae2cda99cc77e9e4410923e7af9fcf1afd6e6921f0c5efe86fd2d6"}
# 2026-05-05 12:21:00,478 [INFO] Daemon stopped.
# Done.

# %%
if __name__ == "__main__":
    CredentialDaemon().run()
